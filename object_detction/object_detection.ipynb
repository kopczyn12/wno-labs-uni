# %%
# !nvidia-smi
# Out:
# Mon May 15 07:35:41 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.4/78.2 GB disk)

# %%
import os
HOME = os.getcwd()
print(HOME)
from ultralytics import YOLO

from IPython.display import display, Image
     

# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

# !pip install roboflow



from roboflow import Roboflow
rf = Roboflow(api_key="HNCj2zgAptbJLvkdy6tv")
project = rf.workspace("michal-kopczynski").project("testwno")
dataset = project.version(1).download("yolov8")
# Out:
# /content/datasets
# /content/datasets/datasets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to testwno-1 in yolov8:: 100%|██████████| 76/76 [00:00<00:00, 3527.82it/s]

# %%
# !yolo detect train data=/content/datasets/datasets/testwno-1/data.yaml model=yolov8n.pt epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !wget https://4.allegroimg.com/original/0c8ac1/9f02911b4a68a6c0f00f397c4c54
# !wget https://www.trotec-blog.com/pl/files/2019/10/PL_tro_blog_9-in-1-ratsche_blogbild_1000x1000.jpg
# !wget https://www.graphitepro.pl/wp-content/uploads/2022/11/srubokret-krzyzowy.jpg
# !wget https://hobbydom.pl/wp-content/uploads/2016/09/Wkretaki_Wiha.jpg
# Out:
# --2023-05-15 08:50:13--  https://4.allegroimg.com/original/0c8ac1/9f02911b4a68a6c0f00f397c4c54
# Resolving 4.allegroimg.com (4.allegroimg.com)... 5.134.213.18, 2a02:dcc:31::
# Connecting to 4.allegroimg.com (4.allegroimg.com)|5.134.213.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 841202 (821K) [image/jpeg]
# Saving to: ‘9f02911b4a68a6c0f00f397c4c54’
#
# 9f02911b4a68a6c0f00 100%[===================>] 821.49K   670KB/s    in 1.2s
#
# 2023-05-15 08:50:16 (670 KB/s) - ‘9f02911b4a68a6c0f00f397c4c54’ saved [841202/841202]
#
# --2023-05-15 08:50:16--  https://www.trotec-blog.com/pl/files/2019/10/PL_tro_blog_9-in-1-ratsche_blogbild_1000x1000.jpg
# Resolving www.trotec-blog.com (www.trotec-blog.com)... 195.252.129.6
# Connecting to www.trotec-blog.com (www.trotec-blog.com)|195.252.129.6|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 518489 (506K) [image/jpeg]
# Saving to: ‘PL_tro_blog_9-in-1-ratsche_blogbild_1000x1000.jpg’
#
# ...

# %%
import os
HOME = os.getcwd()
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.25 source=/content/datasets/datasets/test/
# Out:
# /content/datasets/datasets
# 2023-05-15 08:51:33.973837: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-15 08:51:34.913271: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# image 1/3 /content/datasets/datasets/test/PL_tro_blog_9-in-1-ratsche_blogbild_1000x1000.jpg: 640x640 7.3ms
# image 2/3 /content/datasets/datasets/test/Wkretaki_Wiha.jpg: 448x640 49.3ms
# image 3/3 /content/datasets/datasets/test/srubokret-krzyzowy.jpg: 448x640 5.9ms
# ...

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict3/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
